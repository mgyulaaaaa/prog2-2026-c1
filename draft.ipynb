# %%
import pandas as pd

from single_run import load_test_df

# %%
test_df = load_test_df()

# %%
test_df.head().T
# Out:
#                                                                 0  \
# imdb_id                                                 tt0004972
# drama                                                        True
# history                                                      True
# musical                                                     False
# comedy                                                      False
# music                                                       False
# romance                                                     False
# family                                                      False
# adventure                                                   False
# fantasy                                                     False
# mystery                                                     False
# thriller                                                    False
# sci_fi                                                      False
# ...
